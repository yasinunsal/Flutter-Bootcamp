# %% [markdown]
# <a href="https://colab.research.google.com/github/yasinunsal/Flutter-Bootcamp/blob/main/sentiment_analysis_lstm_dropout_05_hidden_size_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
#  05180000029.ipynb
#  FasterRCNN_112_112_faster_weights.ipynb
#  FasterRCNN_112_112.ipynb
#  FasterRCNN_112_112_mobilenet_v3_large_320_fpn.ipynb
#  FasterRCNN_224_224.ipynb
#  FasterRCNN_448_448.ipynb
#  faster_rcnn_plots_and_summaries
#  fruit-images-for-object-detection
# 'IMDB Dataset.csv'
#  INM702-Task2.ipynb
# 'INM706_Lab7_Bert_classification (1).ipynb'
#  INM706_Lab7_Bert_classification.ipynb
#  sentiment_analysis_gru.ipynb
#  sentiment_analysis_lstm_dropout_02.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_128.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_16_batch_size_256.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_16_batch_size_64.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_16.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_32.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_64.ipynb
#  sentiment_analysis_lstm_dropout_05_hidden_size_8.ipynb
#  sentiment_analysis_lstm_dropout_05.ipynb
#  sentiment_analysis_lstm.ipynb
#  sentiment_lstm.pt
#  Untitled
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled6.ipynb
#  wandb

# %%
import pandas as pd
import numpy as np
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('punkt')
nltk.download("stopwords")
nltk.download('wordnet')
stopwords = set(stopwords.words("english"))

from sklearn.model_selection import train_test_split
import tensorflow as tf

import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader

from tqdm import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix


df = pd.read_csv("IMDB Dataset.csv", sep=",")
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
def remove_html(review):
  review = review.replace("<br /><br />", "")
  return review

def remove_punctuations(review):
  for punctuation in string.punctuation:
    review = review.replace(punctuation, "")
    return review

def remove_digits(review):
  review = "".join(y for y in review if not y.isdigit())
  return review

def remove_nonascii(review):
  review = re.sub(r'[^\x00-\x7f]', r'', review)
  return review

def make_lower(review):
  review = review.lower()
  return review

def remove_stop_words(review):
  review = ' '.join([word for word in review.split() if word not in (stopwords)])
  return review


def clean_review(review):
  review = remove_html(review)
  review = remove_punctuations(review)
  review = remove_digits(review)
  review = remove_nonascii(review)
  review = make_lower(review)
  review = remove_stop_words(review)
  return review

# %%
df["clean_review"] = df["review"].progress_apply(clean_review)

df.head()
# Out:
# 100%|██████████| 50000/50000 [00:08<00:00, 5803.99it/s]
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         clean_review
# 0  one reviewers mentioned watching oz episode ho...
# 1  wonderful little production. filming technique...
# 2  thought wonderful way spend time hot summer we...
# 3  basically there's family little boy (jake) thi...
# 4  petter mattei's "love time money" visually stu...

# %%
df["sentiment"] = df["sentiment"].replace("positive", 1)
df["sentiment"] = df["sentiment"].replace("negative", 0)


df.head()
# Out:
#                                               review  sentiment  \
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1
#
#                                         clean_review
# 0  one reviewers mentioned watching oz episode ho...
# 1  wonderful little production. filming technique...
# 2  thought wonderful way spend time hot summer we...
# 3  basically there's family little boy (jake) thi...
# 4  petter mattei's "love time money" visually stu...

# %%
data = df["clean_review"].values.tolist()
target = df["sentiment"].values.tolist()

train_review, temp_review, train_sentiment, temp_sentiment = train_test_split(
                                                                              data,
                                                                              target,
                                                                              random_state=42,
                                                                              test_size=0.3,
                                                                              )
val_review, test_review, val_sentiment, test_sentiment = train_test_split(
                                                                          temp_review,
                                                                          temp_sentiment,
                                                                          random_state=42,
                                                                          test_size = 0.5,
                                                                          )

# %%
print(tf.__version__)

#tokenizing process
num_words = 10000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words)
tokenizer.fit_on_texts(data)
tokenizer.word_index
# Out:
# 2.15.0
# {'movie': 1,
#  'film': 2,
#  'one': 3,
#  'like': 4,
#  'good': 5,
#  'the': 6,
#  'it': 7,
#  'time': 8,
#  'even': 9,
#  'would': 10,
#  'really': 11,
#  'see': 12,
#  'story': 13,
#  'well': 14,
#  'much': 15,
#  'bad': 16,
#  'get': 17,
#  'great': 18,
#  'also': 19,
#  'people': 20,
#  'first': 21,
#  'made': 22,
#  'make': 23,
#  'way': 24,
#  'movies': 25,
#  'could': 26,
#  'think': 27,
#  'characters': 28,
#  'watch': 29,
#  'films': 30,
#  'two': 31,
#  'many': 32,
#  'seen': 33,
#  'character': 34,
#  'never': 35,
#  'plot': 36,
#  'love': 37,
#  'acting': 38,
#  'life': 39,
#  'best': 40,
#  'know': 41,
#  'show': 42,
#  'little': 43,
#  'i': 44,
#  'ever': 45,
#  'this': 46,
#  'better': 47,
#  'end': 48,
#  'man': 49,
#  'scene': 50,
#  'still': 51,
#  'say': 52,
#  'scenes': 53,
#  'and': 54,
#  'something': 55,
#  'go': 56,
#  'back': 57,
#  'real': 58,
#  "i'm": 59,
#  'watching': 60,
#  'thing': 61,
#  'actors': 62,
#  'though': 63,
#  'years': 64,
#  'funny': 65,
#  'old': 66,
#  'another': 67,
#  'work': 68,
#  'actually': 69,
#  'nothing': 70,
#  'makes': 71,
#  'look': 72,
#  'director': 73,
#  'find': 74,
#  'going': 75,
#  'new': 76,
#  'lot': 77,
#  'all': 78,
#  'every': 79,
#  'part': 80,
#  'cast': 81,
#  'us': 82,
#  'things': 83,
#  'want': 84,
#  'quite': 85,
#  'pretty': 86,
#  'world': 87,
#  'horror': 88,
#  'around': 89,
#  'seems': 90,
#  "can't": 91,
#  'young': 92,
#  'take': 93,
#  'however': 94,
#  'got': 95,
#  'thought': 96,
#  'big': 97,
#  'fact': 98,
#  'enough': 99,
#  'long': 100,
#  "that's": 101,
#  'give': 102,
#  "i've": 103,
#  'that': 104,
#  'may': 105,
#  'in': 106,
#  'comedy': 107,
#  'right': 108,
#  'series': 109,
#  'action': 110,
#  'must': 111,
#  'without': 112,
#  'music': 113,
#  'times': 114,
#  'saw': 115,
#  'always': 116,
#  'original': 117,
#  'role': 118,
#  'come': 119,
#  'almost': 120,
#  'gets': 121,
#  'point': 122,
#  'interesting': 123,
#  'guy': 124,
#  'done': 125,
#  "there's": 126,
#  'whole': 127,
#  'least': 128,
#  'is': 129,
#  'far': 130,
#  'bit': 131,
#  'a': 132,
#  'script': 133,
#  'minutes': 134,
#  'feel': 135,
#  'making': 136,
#  'anything': 137,
#  'might': 138,
#  'since': 139,
#  'me': 140,
#  'family': 141,
#  "he's": 142,
#  'last': 143,
#  'probably': 144,
#  'tv': 145,
#  'performance': 146,
#  'kind': 147,
#  'away': 148,
#  'yet': 149,
#  'but': 150,
#  'fun': 151,
#  'worst': 152,
#  'sure': 153,
#  'rather': 154,
#  'hard': 155,
#  'girl': 156,
#  'anyone': 157,
#  'played': 158,
#  'day': 159,
#  'found': 160,
#  'woman': 161,
#  'looking': 162,
#  'screen': 163,
#  'out': 164,
#  'especially': 165,
#  'although': 166,
#  'believe': 167,
#  'them': 168,
#  'on': 169,
#  'trying': 170,
#  'there': 171,
#  'course': 172,
#  'him': 173,
#  'dvd': 174,
#  'set': 175,
#  'everything': 176,
#  'up': 177,
#  "'s": 178,
#  'goes': 179,
#  'comes': 180,
#  'put': 181,
#  'ending': 182,
#  'maybe': 183,
#  'so': 184,
#  'place': 185,
#  'book': 186,
#  'shows': 187,
#  'three': 188,
#  'worth': 189,
#  'different': 190,
#  'here': 191,
#  'main': 192,
#  'sense': 193,
#  'american': 194,
#  'reason': 195,
#  'looks': 196,
#  'effects': 197,
#  'watched': 198,
#  'play': 199,
#  'true': 200,
#  'actor': 201,
#  'money': 202,
#  'together': 203,
#  'job': 204,
#  'war': 205,
#  'you': 206,
#  'someone': 207,
#  'plays': 208,
#  'high': 209,
#  'instead': 210,
#  'year': 211,
#  'said': 212,
#  'half': 213,
#  'everyone': 214,
#  'takes': 215,
#  'later': 216,
#  'seem': 217,
#  'audience': 218,
#  'special': 219,
#  'beautiful': 220,
#  'again': 221,
#  'left': 222,
#  'seeing': 223,
#  'john': 224,
#  'night': 225,
#  'black': 226,
#  'version': 227,
#  'shot': 228,
#  'excellent': 229,
#  'idea': 230,
#  'house': 231,
#  'mind': 232,
#  'star': 233,
#  'wife': 234,
#  'fan': 235,
#  'death': 236,
#  'used': 237,
#  'else': 238,
#  'simply': 239,
#  'nice': 240,
#  'budget': 241,
#  'poor': 242,
#  'completely': 243,
#  'short': 244,
#  'second': 245,
#  'read': 246,
#  'not': 247,
#  'less': 248,
#  'along': 249,
#  'top': 250,
#  'help': 251,
#  'home': 252,
#  'men': 253,
#  'either': 254,
#  'line': 255,
#  'boring': 256,
#  'dead': 257,
#  'friends': 258,
#  'kids': 259,
#  'production': 260,
#  'try': 261,
#  'camera': 262,
#  'use': 263,
#  'enjoy': 264,
#  'given': 265,
#  'wrong': 266,
#  'low': 267,
#  'father': 268,
#  'need': 269,
#  'classic': 270,
#  'full': 271,
#  'stupid': 272,
#  'next': 273,
#  'performances': 274,
#  'school': 275,
#  'hollywood': 276,
#  'rest': 277,
#  'truly': 278,
#  'her': 279,
#  's': 280,
#  'awful': 281,
#  'video': 282,
#  'couple': 283,
#  'start': 284,
#  'sex': 285,
#  'recommend': 286,
#  'women': 287,
#  'let': 288,
#  'tell': 289,
#  'to': 290,
#  'terrible': 291,
#  'remember': 292,
#  'mean': 293,
#  'came': 294,
#  'understand': 295,
#  'getting': 296,
#  'perhaps': 297,
#  'as': 298,
#  'moments': 299,
#  'name': 300,
#  'keep': 301,
#  'face': 302,
#  'wonderful': 303,
#  'playing': 304,
#  'human': 305,
#  'too': 306,
#  'style': 307,
#  'small': 308,
#  'episode': 309,
#  'perfect': 310,
#  'others': 311,
#  'person': 312,
#  'early': 313,
#  'often': 314,
#  'written': 315,
#  'definitely': 316,
#  'stars': 317,
#  'head': 318,
#  'lines': 319,
#  'dialogue': 320,
#  'gives': 321,
#  'piece': 322,
#  'now': 323,
#  'went': 324,
#  'mother': 325,
#  'case': 326,
#  'title': 327,
#  'absolutely': 328,
#  'finally': 329,
#  'boy': 330,
#  'live': 331,
#  'yes': 332,
#  'laugh': 333,
#  'certainly': 334,
#  'liked': 335,
#  'become': 336,
#  'sort': 337,
#  'worse': 338,
#  'off': 339,
#  'entertaining': 340,
#  'loved': 341,
#  'oh': 342,
#  'lost': 343,
#  'called': 344,
#  'hope': 345,
#  'picture': 346,
#  'felt': 347,
#  'entire': 348,
#  'mr': 349,
#  'several': 350,
#  'supposed': 351,
#  'based': 352,
#  'if': 353,
#  'cinema': 354,
#  'overall': 355,
#  'friend': 356,
#  'sound': 357,
#  'guys': 358,
#  'for': 359,
#  'problem': 360,
#  'drama': 361,
#  'waste': 362,
#  'white': 363,
#  'beginning': 364,
#  'fans': 365,
#  'totally': 366,
#  'dark': 367,
#  'care': 368,
#  'no': 369,
#  'humor': 370,
#  'wanted': 371,
#  'seemed': 372,
#  'direction': 373,
#  'children': 374,
#  'game': 375,
#  'with': 376,
#  'despite': 377,
#  'guess': 378,
#  'lives': 379,
#  'lead': 380,
#  'example': 381,
#  'already': 382,
#  'turn': 383,
#  'evil': 384,
#  'final': 385,
#  'throughout': 386,
#  'becomes': 387,
#  'of': 388,
#  'unfortunately': 389,
#  'able': 390,
#  'quality': 391,
#  "i'd": 392,
#  'days': 393,
#  'history': 394,
#  'fine': 395,
#  'side': 396,
#  'b': 397,
#  'wants': 398,
#  'heart': 399,
#  'horrible': 400,
#  'writing': 401,
#  'amazing': 402,
#  'flick': 403,
#  'killer': 404,
#  'run': 405,
#  'over': 406,
#  'son': 407,
#  'michael': 408,
#  'works': 409,
#  "they're": 410,
#  'close': 411,
#  'act': 412,
#  'art': 413,
#  'kill': 414,
#  'matter': 415,
#  'etc': 416,
#  'or': 417,
#  'tries': 418,
#  'town': 419,
#  'past': 420,
#  'turns': 421,
#  'enjoyed': 422,
#  'gave': 423,
#  'brilliant': 424,
#  'behind': 425,
#  'parts': 426,
#  'be': 427,
#  'stuff': 428,
#  'genre': 429,
#  'car': 430,
#  'what': 431,
#  'eyes': 432,
#  'favorite': 433,
#  'directed': 434,
#  'late': 435,
#  'hand': 436,
#  'expect': 437,
#  'hour': 438,
#  'soon': 439,
#  'do': 440,
#  'obviously': 441,
#  'sometimes': 442,
#  'killed': 443,
#  'thinking': 444,
#  'actress': 445,
#  'girls': 446,
#  'viewer': 447,
#  'child': 448,
#  'starts': 449,
#  'city': 450,
#  'decent': 451,
#  'who': 452,
#  'type': 453,
#  'stop': 454,
#  'self': 455,
#  'highly': 456,
#  'says': 457,
#  'god': 458,
#  'group': 459,
#  'voice': 460,
#  'which': 461,
#  'took': 462,
#  'known': 463,
#  'anyway': 464,
#  'kid': 465,
#  'blood': 466,
#  'heard': 467,
#  'was': 468,
#  'happens': 469,
#  'except': 470,
#  'feeling': 471,
#  'fight': 472,
#  'experience': 473,
#  'then': 474,
#  'coming': 475,
#  'slow': 476,
#  'daughter': 477,
#  'stories': 478,
#  'writer': 479,
#  'moment': 480,
#  'leave': 481,
#  'told': 482,
#  'extremely': 483,
#  'score': 484,
#  'violence': 485,
#  'police': 486,
#  'involved': 487,
#  'lack': 488,
#  'strong': 489,
#  'chance': 490,
#  'cannot': 491,
#  'hit': 492,
#  'wonder': 493,
#  'roles': 494,
#  'particularly': 495,
#  'happen': 496,
#  'hilarious': 497,
#  'including': 498,
#  'living': 499,
#  'ok': 500,
#  'save': 501,
#  'looked': 502,
#  "it's": 503,
#  'simple': 504,
#  'crap': 505,
#  'murder': 506,
#  'obvious': 507,
#  'happened': 508,
#  'cool': 509,
#  'complete': 510,
#  'cut': 511,
#  'please': 512,
#  'age': 513,
#  'serious': 514,
#  'gore': 515,
#  'attempt': 516,
#  'hell': 517,
#  'more': 518,
#  'ago': 519,
#  'song': 520,
#  'shown': 521,
#  'taken': 522,
#  'english': 523,
#  'james': 524,
#  'robert': 525,
#  'seriously': 526,
#  'david': 527,
#  'released': 528,
#  'reality': 529,
#  'jokes': 530,
#  'interest': 531,
#  'opening': 532,
#  'across': 533,
#  'none': 534,
#  'hero': 535,
#  'exactly': 536,
#  'alone': 537,
#  'today': 538,
#  'possible': 539,
#  'sad': 540,
#  'brother': 541,
#  'career': 542,
#  'number': 543,
#  'saying': 544,
#  'hours': 545,
#  "film's": 546,
#  'usually': 547,
#  'cinematography': 548,
#  'talent': 549,
#  'view': 550,
#  'running': 551,
#  'relationship': 552,
#  'annoying': 553,
#  'documentary': 554,
#  'wish': 555,
#  'order': 556,
#  'huge': 557,
#  "'": 558,
#  'whose': 559,
#  'shots': 560,
#  'ridiculous': 561,
#  'taking': 562,
#  'important': 563,
#  'light': 564,
#  'body': 565,
#  'middle': 566,
#  'level': 567,
#  'started': 568,
#  'call': 569,
#  'ends': 570,
#  'female': 571,
#  'husband': 572,
#  'power': 573,
#  'four': 574,
#  'major': 575,
#  "i'll": 576,
#  'word': 577,
#  'turned': 578,
#  'opinion': 579,
#  'change': 580,
#  'mostly': 581,
#  'usual': 582,
#  'silly': 583,
#  'scary': 584,
#  'beyond': 585,
#  'ones': 586,
#  'somewhat': 587,
#  'happy': 588,
#  'words': 589,
#  'room': 590,
#  'rating': 591,
#  'knows': 592,
#  'knew': 593,
#  'country': 594,
#  'disappointed': 595,
#  'novel': 596,
#  'talking': 597,
#  'apparently': 598,
#  'non': 599,
#  'strange': 600,
#  'attention': 601,
#  'upon': 602,
#  'single': 603,
#  'finds': 604,
#  'basically': 605,
#  'modern': 606,
#  'cheap': 607,
#  'due': 608,
#  'jack': 609,
#  'musical': 610,
#  'television': 611,
#  'problems': 612,
#  'miss': 613,
#  'episodes': 614,
#  'clearly': 615,
#  'why': 616,
#  'local': 617,
#  'british': 618,
#  'thriller': 619,
#  'talk': 620,
#  'events': 621,
#  'five': 622,
#  'sequence': 623,
#  'class': 624,
#  'about': 625,
#  'french': 626,
#  'moving': 627,
#  'ten': 628,
#  'earth': 629,
#  'fast': 630,
#  'tells': 631,
#  'review': 632,
#  'predictable': 633,
#  'before': 634,
#  'other': 635,
#  'team': 636,
#  'songs': 637,
#  'comic': 638,
#  'straight': 639,
#  'whether': 640,
#  'die': 641,
#  'add': 642,
#  'dialog': 643,
#  'entertainment': 644,
#  'sets': 645,
#  'future': 646,
#  'enjoyable': 647,
#  'appears': 648,
#  'near': 649,
#  'space': 650,
#  'easily': 651,
#  'hate': 652,
#  'soundtrack': 653,
#  'giving': 654,
#  'bring': 655,
#  'lots': 656,
#  'similar': 657,
#  'romantic': 658,
#  'george': 659,
#  'supporting': 660,
#  'release': 661,
#  'mention': 662,
#  'within': 663,
#  'down': 664,
#  'filmed': 665,
#  'message': 666,
#  'clear': 667,
#  'sequel': 668,
#  'falls': 669,
#  'needs': 670,
#  'dull': 671,
#  'bunch': 672,
#  'suspense': 673,
#  'eye': 674,
#  'surprised': 675,
#  'showing': 676,
#  'tried': 677,
#  'sorry': 678,
#  'certain': 679,
#  'working': 680,
#  'ways': 681,
#  'easy': 682,
#  'theme': 683,
#  'theater': 684,
#  'among': 685,
#  'named': 686,
#  "what's": 687,
#  'storyline': 688,
#  'monster': 689,
#  'stay': 690,
#  'king': 691,
#  'effort': 692,
#  'fall': 693,
#  'minute': 694,
#  'stand': 695,
#  'gone': 696,
#  'rock': 697,
#  'using': 698,
#  'feature': 699,
#  'comments': 700,
#  'buy': 701,
#  'tale': 702,
#  'sister': 703,
#  'typical': 704,
#  'editing': 705,
#  'dr': 706,
#  'mystery': 707,
#  'deal': 708,
#  'avoid': 709,
#  'doubt': 710,
#  'kept': 711,
#  'nearly': 712,
#  'feels': 713,
#  'subject': 714,
#  'th': 715,
#  'viewing': 716,
#  'fantastic': 717,
#  'elements': 718,
#  'oscar': 719,
#  'points': 720,
#  'realistic': 721,
#  'means': 722,
#  'greatest': 723,
#  'parents': 724,
#  'famous': 725,
#  'okay': 726,
#  'check': 727,
#  'imagine': 728,
#  'richard': 729,
#  'viewers': 730,
#  'crime': 731,
#  'rent': 732,
#  'did': 733,
#  'form': 734,
#  'actual': 735,
#  'general': 736,
#  'lady': 737,
#  'peter': 738,
#  'dog': 739,
#  'follow': 740,
#  'believable': 741,
#  'red': 742,
#  'period': 743,
#  'brought': 744,
#  'material': 745,
#  'move': 746,
#  'at': 747,
#  'somehow': 748,
#  'forget': 749,
#  'begins': 750,
#  'animation': 751,
#  'reviews': 752,
#  'leads': 753,
#  'paul': 754,
#  'weak': 755,
#  'he': 756,
#  'figure': 757,
#  'hear': 758,
#  'sit': 759,
#  'surprise': 760,
#  'average': 761,
#  'sequences': 762,
#  'open': 763,
#  'killing': 764,
#  'atmosphere': 765,
#  'premise': 766,
#  'eventually': 767,
#  'wait': 768,
#  'tom': 769,
#  'learn': 770,
#  'sci': 771,
#  'deep': 772,
#  'fi': 773,
#  'expected': 774,
#  'whatever': 775,
#  'particular': 776,
#  'lame': 777,
#  'poorly': 778,
#  'dance': 779,
#  'note': 780,
#  'indeed': 781,
#  'imdb': 782,
#  't': 783,
#  'situation': 784,
#  'shame': 785,
#  're': 786,
#  'third': 787,
#  'york': 788,
#  'box': 789,
#  'truth': 790,
#  'decided': 791,
#  'free': 792,
#  'hot': 793,
#  "who's": 794,
#  'season': 795,
#  'difficult': 796,
#  'needed': 797,
#  'acted': 798,
#  'leaves': 799,
#  'emotional': 800,
#  'possibly': 801,
#  'romance': 802,
#  'unless': 803,
#  'gay': 804,
#  'boys': 805,
#  'footage': 806,
#  'sexual': 807,
#  'write': 808,
#  'western': 809,
#  'doctor': 810,
#  'became': 811,
#  'forced': 812,
#  'reading': 813,
#  'credits': 814,
#  'memorable': 815,
#  'air': 816,
#  'begin': 817,
#  'otherwise': 818,
#  'de': 819,
#  'crew': 820,
#  'question': 821,
#  'meet': 822,
#  'society': 823,
#  'male': 824,
#  'are': 825,
#  'meets': 826,
#  'plus': 827,
#  'cheesy': 828,
#  "let's": 829,
#  'hands': 830,
#  'superb': 831,
#  'screenplay': 832,
#  'street': 833,
#  'interested': 834,
#  'features': 835,
#  'perfectly': 836,
#  'laughs': 837,
#  'beauty': 838,
#  'masterpiece': 839,
#  'effect': 840,
#  'nature': 841,
#  'stage': 842,
#  'forward': 843,
#  'previous': 844,
#  'e': 845,
#  'comment': 846,
#  'sounds': 847,
#  'badly': 848,
#  'japanese': 849,
#  'weird': 850,
#  'inside': 851,
#  'personal': 852,
#  'island': 853,
#  'quickly': 854,
#  'total': 855,
#  'keeps': 856,
#  'towards': 857,
#  'result': 858,
#  'america': 859,
#  'crazy': 860,
#  'battle': 861,
#  'setting': 862,
#  'worked': 863,
#  'earlier': 864,
#  'background': 865,
#  'incredibly': 866,
#  'mess': 867,
#  'cop': 868,
#  'writers': 869,
#  'realize': 870,
#  'dumb': 871,
#  'unique': 872,
#  'fire': 873,
#  'copy': 874,
#  'lee': 875,
#  'mark': 876,
#  'powerful': 877,
#  'my': 878,
#  'dramatic': 879,
#  'business': 880,
#  'older': 881,
#  'rate': 882,
#  'pay': 883,
#  'directors': 884,
#  'himself': 885,
#  'girlfriend': 886,
#  'following': 887,
#  'plenty': 888,
#  'directing': 889,
#  'joke': 890,
#  'various': 891,
#  'creepy': 892,
#  'baby': 893,
#  'appear': 894,
#  'brings': 895,
#  'development': 896,
#  'dream': 897,
#  'front': 898,
#  'ask': 899,
#  'water': 900,
#  'rich': 901,
#  'admit': 902,
#  'apart': 903,
#  'bill': 904,
#  'fairly': 905,
#  'joe': 906,
#  'political': 907,
#  'leading': 908,
#  'reasons': 909,
#  'portrayed': 910,
#  'spent': 911,
#  'telling': 912,
#  'cover': 913,
#  'present': 914,
#  'fighting': 915,
#  'outside': 916,
#  'wasted': 917,
#  'fails': 918,
#  'era': 919,
#  'deserves': 920,
#  'gun': 921,
#  'success': 922,
#  'party': 923,
#  'meant': 924,
#  "'the": 925,
#  'list': 926,
#  'expecting': 927,
#  'break': 928,
#  'attempts': 929,
#  'create': 930,
#  'william': 931,
#  'ended': 932,
#  'ideas': 933,
#  'secret': 934,
#  'agree': 935,
#  'manages': 936,
#  'missing': 937,
#  'recently': 938,
#  'talented': 939,
#  'twist': 940,
#  'zombie': 941,
#  'caught': 942,
#  'fantasy': 943,
#  'unlike': 944,
#  'hardly': 945,
#  'odd': 946,
#  'german': 947,
#  'large': 948,
#  'cute': 949,
#  'produced': 950,
#  'return': 951,
#  'match': 952,
#  'co': 953,
#  'while': 954,
#  'clever': 955,
#  'laughing': 956,
#  'itself': 957,
#  'plain': 958,
#  'nudity': 959,
#  'members': 960,
#  'remake': 961,
#  'disney': 962,
#  'escape': 963,
#  'italian': 964,
#  'office': 965,
#  'from': 966,
#  'potential': 967,
#  'created': 968,
#  'villain': 969,
#  'casting': 970,
#  'pace': 971,
#  'missed': 972,
#  'flat': 973,
#  'wrote': 974,
#  "we're": 975,
#  'pure': 976,
#  'married': 977,
#  'cartoon': 978,
#  'waiting': 979,
#  'state': 980,
#  'filled': 981,
#  'century': 982,
#  'filmmakers': 983,
#  'public': 984,
#  'incredible': 985,
#  'mentioned': 986,
#  'cold': 987,
#  'hold': 988,
#  'visual': 989,
#  'sadly': 990,
#  'familiar': 991,
#  'slightly': 992,
#  'spoilers': 993,
#  'van': 994,
#  'science': 995,
#  'considering': 996,
#  'train': 997,
#  "don't": 998,
#  'died': 999,
#  'speak': 1000,
#  ...}

# %%
train_review_tokens = tokenizer.texts_to_sequences(train_review)
val_review_tokens = tokenizer.texts_to_sequences(val_review)
test_review_tokens = tokenizer.texts_to_sequences(test_review)

print(train_review[1])
print(train_review_tokens[1])
# Out:
# good ppv, like wrestlemania xx years later, wwe crammed many matches it, matches useless. i'm going go every match card would take forever do.however major highlights included huge pop demolition winning tag team belts haku andre giant, first ever mixed tag match featuring randy savage sensational queen sherri vs dusty rhodes late sapphire first ever clash ultimate warrior hulk hogan.some matches complete waste time. like bolsheviks vs hart foundation seconds long, koko b ware vs rick martel short big bossman vs akeem short.mr perfect vs brutus beefcake ted dibiase vs jake 'the snake' roberts good indeed.overall grade - b
# [5, 4, 9009, 64, 216, 5387, 32, 4403, 7, 4403, 3054, 59, 75, 56, 79, 952, 3305, 10, 93, 1332, 440, 94, 575, 3351, 1863, 557, 1491, 1648, 3879, 636, 5369, 1256, 21, 45, 1844, 3879, 952, 1917, 3772, 3655, 7192, 1616, 1502, 8334, 435, 21, 45, 6477, 2033, 3815, 5824, 5921, 1178, 4403, 510, 362, 8, 4, 1502, 4577, 6343, 1543, 100, 397, 1502, 3690, 244, 97, 1502, 244, 349, 310, 1502, 2618, 1502, 3555, 925, 2588, 5, 781, 355, 1155, 397]

# %%
#padding process

maxlen = 256
pad_sequences = tf.keras.preprocessing.sequence.pad_sequences
train_review_pad = pad_sequences(train_review_tokens, maxlen=maxlen)
val_review_pad = pad_sequences(val_review_tokens, maxlen=maxlen)
test_review_pad = pad_sequences(test_review_tokens, maxlen=maxlen)

print(train_review_pad.shape)
print(val_review_pad.shape)
print(test_review_pad.shape)
# Out:
# (35000, 256)
# (7500, 256)
# (7500, 256)

# %%
batch_size = 128

train_set = TensorDataset(torch.from_numpy(train_review_pad), torch.tensor(train_sentiment))
val_set = TensorDataset(torch.from_numpy(val_review_pad), torch.tensor(val_sentiment))
test_set = TensorDataset(torch.from_numpy(test_review_pad), torch.tensor(test_sentiment))

train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size)
val_loader = DataLoader(val_set, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_set, shuffle=True, batch_size=batch_size)

# %%
class LSTMModel(nn.Module):
  def __init__(
    self,
    vocab_size,
    output_size,
    hidden_size,
    embedding_size,
    n_layers,
    dropout
    ):

    super(LSTMModel, self).__init__()
    self.embedding = nn.Embedding(vocab_size, embedding_size)
    #self.dropout = nn.Dropout(dropout)
    self.dropout1d = nn.Dropout1d(dropout)
    self.lstm = nn.LSTM(embedding_size, hidden_size, n_layers, dropout=dropout, batch_first=True)
    #self.dropout = nn.Dropout(0.3)
    self.fc = nn.Linear(hidden_size, output_size)
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    x = x.long()
    x = self.embedding(x)
    x = self.dropout1d(x)
    out, _ =  self.lstm(x)
    out = out[:, -1, :]
    #out = self.dropout(out)
    out = self.fc(out)
    out = self.sigmoid(out)

    return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
vocab_size = num_words
output_size = 1
embedding_size = 256
hidden_size = 128
n_layers = 2
dropout = 0.5

# model initialization
model = LSTMModel(vocab_size, output_size, hidden_size, embedding_size, n_layers, dropout)
print(model)
# Out:
# LSTMModel(
#   (embedding): Embedding(10000, 256)
#   (dropout1d): Dropout1d(p=0.5, inplace=False)
#   (lstm): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# training config
#lr = 5e-4
#criterion = nn.CrossEntropyLoss()
lr = 0.001
criterion = nn.BCELoss()
optim = Adam(model.parameters(), lr=lr)
grad_clip = 5
epochs = 10
print_every = 1
history = {
    'train_loss': [],
    'train_acc': [],
    'val_loss': [],
    'val_acc': [],
    'epochs': epochs
}

# %%
# train loop
model = model.to(device)

epochloop = tqdm(range(epochs), position=0, desc='Training', leave=True)

for e in epochloop:

  #train
  model.train()

  train_loss = 0
  train_acc = 0

  for id, (feature, target) in enumerate(train_loader):
      epochloop.set_postfix_str(f'Training batch {id}/{len(train_loader)}')
      feature, target = feature.to(device), target.to(device)
      optim.zero_grad()
      out = model(feature)

      # acc
      predicted = torch.tensor([1 if i == True else 0 for i in out > 0.5], device=device)
      equals = predicted == target
      acc = torch.mean(equals.type(torch.FloatTensor))
      train_acc += acc.item()

      # loss
      loss = criterion(out.squeeze(), target.float())
      train_loss += loss.item()
      loss.backward()

      # clip grad
      nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

      # update optimizer
      optim.step()

      del feature, target, predicted

  history['train_loss'].append(train_loss / len(train_loader))
  history['train_acc'].append(train_acc / len(train_loader))

  #validation
  model.eval()

  val_loss = 0
  val_acc = 0

  with torch.no_grad():
      for id, (feature, target) in enumerate(val_loader):
          epochloop.set_postfix_str(f'Validation batch {id}/{len(val_loader)}')
          feature, target = feature.to(device), target.to(device)
          out = model(feature)

          # acc
          predicted = torch.tensor([1 if i == True else 0 for i in out > 0.5], device=device)
          equals = predicted == target
          acc = torch.mean(equals.type(torch.FloatTensor))
          val_acc += acc.item()

          # loss
          loss = criterion(out.squeeze(), target.float())
          val_loss += loss.item()

          del feature, target, predicted

      history['val_loss'].append(val_loss / len(val_loader))
      history['val_acc'].append(val_acc / len(val_loader))

  # reset model mode
  model.train()

  # add epoch meta info
  epochloop.set_postfix_str(f'Val Loss: {val_loss / len(val_loader):.3f} | Val Acc: {val_acc / len(val_loader):.3f}')

  # print epoch
  if (e+1) % print_every == 0:
      epochloop.write(f'Epoch {e+1}/{epochs} | Train Loss: {train_loss / len(train_loader):.3f} Train Acc: {train_acc / len(train_loader):.3f} | Val Loss: {val_loss / len(val_loader):.3f} Val Acc: {val_acc / len(val_loader):.3f}')
      epochloop.update()
# Out:
# Training:  20%|██        | 2/10 [00:07<00:55,  6.90s/it, Training batch 11/274]
# Epoch 1/10 | Train Loss: 0.597 Train Acc: 0.675 | Val Loss: 0.436 Val Acc: 0.810
# Training:  40%|████      | 4/10 [00:12<00:22,  3.72s/it, Training batch 11/274]
# Epoch 2/10 | Train Loss: 0.457 Train Acc: 0.790 | Val Loss: 0.358 Val Acc: 0.856
# Training:  50%|█████     | 5/10 [00:17<00:15,  3.15s/it, Training batch 11/274]
# Epoch 3/10 | Train Loss: 0.389 Train Acc: 0.827 | Val Loss: 0.314 Val Acc: 0.870
# Training:  70%|███████   | 7/10 [00:22<00:11,  3.70s/it, Training batch 11/274]
# Epoch 4/10 | Train Loss: 0.364 Train Acc: 0.843 | Val Loss: 0.307 Val Acc: 0.872
# Training:  80%|████████  | 8/10 [00:27<00:06,  3.24s/it, Training batch 11/274]
# Epoch 5/10 | Train Loss: 0.349 Train Acc: 0.848 | Val Loss: 0.277 Val Acc: 0.885
# Training:  90%|█████████ | 9/10 [00:33<00:03,  3.71s/it, Training batch 11/274]
# Epoch 6/10 | Train Loss: 0.324 Train Acc: 0.860 | Val Loss: 0.268 Val Acc: 0.889
# Training: 11it [00:38,  4.10s/it, Training batch 11/274]
# Epoch 7/10 | Train Loss: 0.304 Train Acc: 0.871 | Val Loss: 0.270 Val Acc: 0.886
# Training: 12it [00:43,  3.48s/it, Training batch 11/274]
# Epoch 8/10 | Train Loss: 0.300 Train Acc: 0.874 | Val Loss: 0.268 Val Acc: 0.890
# Training: 13it [00:48,  3.89s/it, Training batch 11/274]
# Epoch 9/10 | Train Loss: 0.289 Train Acc: 0.878 | Val Loss: 0.256 Val Acc: 0.891
# Training: 100%|██████████| 10/10 [00:54<00:00,  5.40s/it, Val Loss: 0.266 | Val Acc: 0.891]
# Epoch 10/10 | Train Loss: 0.278 Train Acc: 0.883 | Val Loss: 0.266 Val Acc: 0.891

# %%
# plot loss
plt.figure(figsize=(8, 5))
plt.plot(range(history['epochs']), history['train_acc'], label='Train Acc')
plt.plot(range(history['epochs']), history['val_acc'], label='Val Acc')
plt.legend()
plt.show()

# %%
# plot loss
plt.figure(figsize=(8, 5))
plt.plot(range(history['epochs']), history['train_loss'], label='Train Loss')
plt.plot(range(history['epochs']), history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# %%
model.eval()

# metrics
test_loss = 0
test_acc = 0

all_target = []
all_predicted = []

testloop = tqdm(test_loader, leave=True, desc='Inference')
with torch.no_grad():
    for feature, target in testloop:
        feature, target = feature.to(device), target.to(device)

        out = model(feature)

        predicted = torch.tensor([1 if i == True else 0 for i in out > 0.5], device=device)
        equals = predicted == target
        acc = torch.mean(equals.type(torch.FloatTensor))
        test_acc += acc.item()

        loss = criterion(out.squeeze(), target.float())
        test_loss += loss.item()

        all_target.extend(target.cpu().numpy())
        all_predicted.extend(predicted.cpu().numpy())

    print(f'Accuracy: {test_acc/len(test_loader):.4f}, Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Inference: 100%|██████████| 59/59 [00:00<00:00, 107.59it/s]
# Accuracy: 0.8976, Loss: 0.2648

# %%
print(classification_report(all_predicted, all_target))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      3556
#            1       0.92      0.88      0.90      3944
#
#     accuracy                           0.90      7500
#    macro avg       0.90      0.90      0.90      7500
# weighted avg       0.90      0.90      0.90      7500

# %%
cm = confusion_matrix(all_target, all_predicted)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel("Predictions")
plt.ylabel("True Labels")
plt.title('Confusion Matrix')
plt.show()

# %%
def review_pred(review, model):
  review = [review]
  for i in range(len(review)):
    review[i] = clean_review(review[i])

  review = tokenizer.texts_to_sequences(review)
  review = pad_sequences(review, maxlen=maxlen, dtype="int32")

  sentiment = model(torch.tensor(review).to(device)).to(device)

  pred = sentiment.cpu().detach().numpy()
  print(pred.item())

  if(pred < 0.5):
      print("negative")
  elif (pred >= 0.5):
      print("positive")

review = "this movie is a masterpiece"

review_pred(review, model)

review = "this movie is terrible"

review_pred(review, model)

review = "this movie is not terrible, it's great!"

review_pred(review, model)

review = "this movie is not great, it's terrible!"

review_pred(review, model)
# Out:
# 0.46290069818496704
# negative
# 0.09491503983736038
# negative
# 0.22927317023277283
# negative
# 0.3361736536026001
# negative
